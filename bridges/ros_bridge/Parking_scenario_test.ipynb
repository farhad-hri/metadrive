# %%
from metadrive import (
 MultiAgentParkingLotEnv
)
from metadrive.component.traffic_participants.pedestrian import Pedestrian
import pprint

env = MultiAgentParkingLotEnv(
    {
        "horizon": 100000,
        "vehicle_config": {
            "lidar": {
                "num_lasers": 72,
                "num_others": 0,
                "distance": 40
            },
            "show_lidar": False,
        },
        "debug_static_world": False,
        "debug_physics_world": False,
        "use_render": False,
        "debug": True,
        "manual_control": True,
        "num_agents": 2,
        "delay_done": 10,
        "parking_space_num": 4,
    }
)
o, _ = env.reset()
obj_1 = env.engine.spawn_object(Pedestrian, position=[30, 0], heading_theta=0, random_seed=1)
obj_1.set_velocity([1, 0], 1, in_local_frame=True)
total_r = 0
ep_s = 0

current_map = env.current_map
# List all parking spots.
# Depending on your map implementation, parking_space might be a list or dict of destination roads.
parking_spots = current_map.parking_space
pprint.pprint(current_map)
parking_length = current_map.parking_lot.parking_space_length
parking_width = current_map.parking_lot.parking_space_width
print(dir(parking_spots))
# For clarity, we print out each parking spot's key details.
# In this example, we assume each parking spot is represented as a Road object.
print("Total parking spots available:", len(parking_spots))
for idx, spot in enumerate(parking_spots):
    print(dir(spot))
    # Display some representative info about the spot (e.g., start and end nodes)
    print("Parking Spot {}:".format(idx))
    print("  Start Node:", spot.start_node)
    print("  End Node:", spot.end_node)
    print(current_map.road_network.shortest_path(spot.start_node, spot.end_node))
    print("  Length:", spot.length if hasattr(spot, "length") else "N/A")
    pprint.pprint(spot.lane_index)
    # For spot lane 
    spot.get_lanes(current_map.road_network)
    # For all lanes
    current_map.parking_lot.block_network.get_all_lanes()
    #print(current_map.road_network.get_lane(spot.lane_index))
    #print(current_map.parking_lot.block_network.get_all_lanes())
    print("-" * 30)

# Optionally, pretty-print the entire parking_space structure.
pprint.pprint(parking_spots)
# Out:
# [INFO] Environment: MultiAgentParkingLotEnv
# [INFO] MetaDrive version: 0.4.3
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector()]
# [INFO] Render Mode: none
# [INFO] Horizon (Max steps per agent): 100000
# [WARNING] When reaching max steps, both 'terminate' and 'truncate will be True.Generally, only the `truncate` should be `True`. (base_env.py:395)
# [INFO] Assets version: 0.4.3
# [INFO] Known Pipes: glxGraphicsPipe
# [DEBUG] Load Vehicle Module: Lidar (distance_detector.py:114)
# [DEBUG] Load Vehicle Module: SideDetector (distance_detector.py:114)
# [DEBUG] Load Vehicle Module: LaneLineDetector (distance_detector.py:114)
# [INFO] Start Scenario Index: 0, Num Scenarios : 1
# [DEBUG] FirstPGBlock is attached to the world. (base_object.py:233)
# [DEBUG] ParkingLot is attached to the world. (base_object.py:233)
# [DEBUG] TInterSection is attached to the world. (base_object.py:233)
# [DEBUG] FirstPGBlock is detached from the world. (base_object.py:251)
# [DEBUG] ParkingLot is detached from the world. (base_object.py:251)
# [DEBUG] TInterSection is detached from the world. (base_object.py:251)
# [DEBUG] FirstPGBlock is attached to the world. (base_object.py:233)
# [DEBUG] ParkingLot is attached to the world. (base_object.py:233)
# [DEBUG] TInterSection is attached to the world. (base_object.py:233)
# [DEBUG] Can not attach object FirstPGBlock to world, as it is already attached! (base_object.py:235)
# [DEBUG] Can not attach object ParkingLot to world, as it is already attached! (base_object.py:235)
# [DEBUG] Can not attach object TInterSection to world, as it is already attached! (base_object.py:235)
# [DEBUG] StaticDefaultVehicle is attached to the world. (base_object.py:233)
# [DEBUG] StaticDefaultVehicle is attached to the world. (base_object.py:233)
# [DEBUG] Terrain is attached to the world. (base_object.py:233)
# [DEBUG] Pedestrian is attached to the world. (base_object.py:233)
# MAParkingLotMap, ID:de686939-328d-407a-9a25-2f41d5067da4
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
# Total parking spots available: 4
# ['NEGATIVE_DIR', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__neg__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slotnames__', '__str__', '__subclasshook__', '__weakref__', 'block_ID', 'end_node', 'get_lanes', 'is_negative_road', 'is_valid_road', 'lane_index', 'lane_num', 'start_node', 'to_json']
# Parking Spot 0:
#   Start Node: 1P1_1_
#   End Node: 1P1_2_
# []
#   Length: N/A
# <bound method Road.lane_index of Road from 1P1_1_ to 1P1_2_>
# ------------------------------
# ['NEGATIVE_DIR', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__neg__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slotnames__', '__str__', '__subclasshook__', '__weakref__', 'block_ID', 'end_node', 'get_lanes', 'is_negative_road', 'is_valid_road', 'lane_index', 'lane_num', 'start_node', 'to_json']
# Parking Spot 1:
#   Start Node: 1P2_1_
#   End Node: 1P2_2_
# []
#   Length: N/A
# <bound method Road.lane_index of Road from 1P2_1_ to 1P2_2_>
# ------------------------------
# ['NEGATIVE_DIR', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__neg__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slotnames__', '__str__', '__subclasshook__', '__weakref__', 'block_ID', 'end_node', 'get_lanes', 'is_negative_road', 'is_valid_road', 'lane_index', 'lane_num', 'start_node', 'to_json']
# Parking Spot 2:
#   Start Node: 1P3_1_
#   End Node: 1P3_2_
# []
#   Length: N/A
# <bound method Road.lane_index of Road from 1P3_1_ to 1P3_2_>
# ------------------------------
# ['NEGATIVE_DIR', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__neg__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slotnames__', '__str__', '__subclasshook__', '__weakref__', 'block_ID', 'end_node', 'get_lanes', 'is_negative_road', 'is_valid_road', 'lane_index', 'lane_num', 'start_node', 'to_json']
# Parking Spot 3:
#   Start Node: 1P4_1_
#   End Node: 1P4_2_
# []
#   Length: N/A
# <bound method Road.lane_index of Road from 1P4_1_ to 1P4_2_>
# ------------------------------
# [Road from 1P1_1_ to 1P1_2_,
#  Road from 1P2_1_ to 1P2_2_,
#  Road from 1P3_1_ to 1P3_2_,
#  Road from 1P4_1_ to 1P4_2_]

# %%
# Out:
# {'key1': [1, 2, 3], 'key2': {'another_key': [4, 5, 6], 'nested_key': 'value'}}
